# %% [markdown]
# # Reproducible Data Analysis in Jupyter

# %% [markdown]
# ## Author : Mouad Et-tali

# %%
import os
from urllib.request import urlretrieve
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
from data_package.data import get_fremont_data

data = get_fremont_data()

# %%
data.head()
# Out:
#                      Total  East  West
# Date
# 2019-11-01 00:00:00   12.0   7.0   5.0
# 2019-11-01 01:00:00    7.0   0.0   7.0
# 2019-11-01 02:00:00    1.0   0.0   1.0
# 2019-11-01 03:00:00    6.0   6.0   0.0
# 2019-11-01 04:00:00    6.0   5.0   1.0

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data.resample('W').sum().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ax = data.resample('D').sum().rolling(365).sum().plot()
ax.set_ylim(0,None)
# Out:
# (0.0, 2526785.8)

# %%
data.groupby(data.index.time).mean().plot();

# %%
pivoted = data.pivot_table('Total', index =data.index.time, columns = data.index.date)
pivoted.iloc[:5,:5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 00:00:00        13.0        18.0        11.0        15.0        11.0
# 01:00:00        10.0         3.0         8.0        15.0        17.0
# 02:00:00         2.0         9.0         7.0         9.0         3.0
# 03:00:00         5.0         3.0         4.0         3.0         6.0
# 04:00:00         7.0         8.0         9.0         5.0         3.0

# %%
pivoted.plot(legend=False, alpha = 0.01)
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# Hypothesis :  commute days have bike counts peaks around the morning and at end of work hours, while *weekends* and *holidays* have a smoother peak
